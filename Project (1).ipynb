# %% [markdown]
# # 1. Import libraries and dataset and understand it.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings("ignore")

# %% [markdown]
# First we have imported all the libraries that are used in our project

# %% [markdown]
# Pandas is built on top of two core Python libraries—
# matplotlib for data visualization and MATLAB-style interface
# NumPy for mathematical operations.
# Seaborn is a library that uses Matplotlib underneath to plot graphs. It will be used to visualize random distributions.

# %%
loan=pd.read_csv("C:\\Users\\shwet\\Downloads\\Project 1-2\\Project 1\\loan.csv")
loan
# Out:
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0      1077501    1296599       5000         5000           4975.0
# 1      1077430    1314167       2500         2500           2500.0
# 2      1077175    1313524       2400         2400           2400.0
# 3      1076863    1277178      10000        10000          10000.0
# 4      1075358    1311748       3000         3000           3000.0
# ...        ...        ...        ...          ...              ...
# 39712    92187      92174       2500         2500           1075.0
# 39713    90665      90607       8500         8500            875.0
# 39714    90395      90390       5000         5000           1325.0
# 39715    90376      89243       5000         5000            650.0
# 39716    87023      86999       7500         7500            800.0
#
#              term int_rate  installment grade emp_length  ...  \
# 0       36 months   10.65%       162.87     B  10+ years  ...
# ...

# %% [markdown]
# Import pandas and the dataset as a Dataframe with read_csv method
# header: this allows you to specify which row will be used as column names for our dataframe loan.
# Expected an int value or a list of int values. Default value is header=0 ,
# which means the first row of the CSV file will be treated as column names.
# There we have 39717 rows and 111 columns.

# %%
loan.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#   int_rate  installment grade emp_length  ...         purpose    dti  \
# 0   10.65%       162.87     B  10+ years  ...     credit_card  27.65
# 1   15.27%        59.83     C   < 1 year  ...             car   1.00
# 2   15.96%        84.33     C  10+ years  ...  small_business   8.72
# 3   13.49%       339.31     C  10+ years  ...           other  20.00
# 4   12.69%        67.79     B     1 year  ...           other  17.94
#
#     total_pymnt total_pymnt_inv  total_rec_prncp  total_rec_int  last_pymnt_d  \
# ...

# %% [markdown]
# display default(first five records) from the dataset to check the dataset from the starting

# %%
loan.tail()
# Out:
#           id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 39712  92187      92174       2500         2500           1075.0   36 months
# 39713  90665      90607       8500         8500            875.0   36 months
# 39714  90395      90390       5000         5000           1325.0   36 months
# 39715  90376      89243       5000         5000            650.0   36 months
# 39716  87023      86999       7500         7500            800.0   36 months
#
#       int_rate  installment grade emp_length  ...             purpose    dti  \
# 39712    8.07%        78.42     A    4 years  ...    home_improvement  11.33
# 39713   10.28%       275.38     C    3 years  ...         credit_card   6.40
# 39714    8.07%       156.84     A   < 1 year  ...  debt_consolidation   2.30
# 39715    7.43%       155.38     A   < 1 year  ...               other   3.72
# 39716   13.75%       255.43     E   < 1 year  ...  debt_consolidation  14.29
#
# ...

# %% [markdown]
# display default(last five records) from the dataset to check the dataset from the end

# %% [markdown]
# # 2. List down the number of rows and columns

# %%
loan.shape
# Out:
# (39717, 23)

# %% [markdown]
# rows=39717 and columns=23

# %%
loan.info
# Out:
# <bound method DataFrame.info of             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0      1077501    1296599       5000         5000           4975.0
# 1      1077430    1314167       2500         2500           2500.0
# 2      1077175    1313524       2400         2400           2400.0
# 3      1076863    1277178      10000        10000          10000.0
# 4      1075358    1311748       3000         3000           3000.0
# ...        ...        ...        ...          ...              ...
# 39712    92187      92174       2500         2500           1075.0
# 39713    90665      90607       8500         8500            875.0
# 39714    90395      90390       5000         5000           1325.0
# 39715    90376      89243       5000         5000            650.0
# 39716    87023      86999       7500         7500            800.0
#
#              term int_rate  installment grade emp_length  ...  \
# 0       36 months   10.65%       162.87     B  10+ years  ...
# ...

# %% [markdown]
# #  3. ‘Int_rate’ column is character type. With the help of lambda function convert into float type

# %%
loan.int_rate=loan["int_rate"].apply(lambda x : x.replace("%","")).astype(float)

# %%
loan.int_rate
# Out:
# 0        10.65
# 1        15.27
# 2        15.96
# 3        13.49
# 4        12.69
#          ...
# 39712     8.07
# 39713    10.28
# 39714     8.07
# 39715     7.43
# 39716    13.75
# Name: int_rate, Length: 39717, dtype: float64

# %% [markdown]
#  convert the interest rate column in a loan dataset from a string format with a percentage symbol ("%") to a float format.

# %% [markdown]
# loan["int_rate"]: Accesses the "int_rate" column in the "loan" dataset.
# .apply(lambda x : x.replace("%","")): Applies a lambda function to each value in the "int_rate" column. The lambda function takes the value "x" and replaces any "%" symbol with an empty string (i.e., removes it).
# .astype(float): Converts the resulting values to a float data type.
# Overall, this code snippet replaces the "%" symbol in the "int_rate" column with an empty string and converts the resulting values to float data type. This is commonly done in data preprocessing to make the data easier to work with and analyze.

# %% [markdown]
# # 4. Check the datatype of each column

# %%
loan.dtypes
# Out:
# id                       int64
# member_id                int64
# loan_amnt                int64
# funded_amnt              int64
# funded_amnt_inv        float64
# term                    object
# int_rate               float64
# installment            float64
# grade                   object
# emp_length              object
# annual_inc             float64
# verification_status     object
# loan_status             object
# purpose                 object
# dti                    float64
# total_pymnt            float64
# total_pymnt_inv        float64
# total_rec_prncp        float64
# total_rec_int          float64
# last_pymnt_d            object
# last_pymnt_amnt        float64
# Unnamed: 21            float64
# Unnamed: 22            float64
# dtype: object

# %% [markdown]
# available datatypes are int, float, and object

# %%
loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   39717 non-null  int64
#  1   member_id            39717 non-null  int64
#  2   loan_amnt            39717 non-null  int64
#  3   funded_amnt          39717 non-null  int64
#  4   funded_amnt_inv      39717 non-null  float64
#  5   term                 39717 non-null  object
#  6   int_rate             39717 non-null  float64
#  7   installment          39717 non-null  float64
#  8   grade                39717 non-null  object
#  9   emp_length           38642 non-null  object
#  10  annual_inc           39717 non-null  float64
#  11  verification_status  39717 non-null  object
#  12  loan_status          39717 non-null  object
#  13  purpose              39717 non-null  object
#  14  dti                  39717 non-null  float64
# ...

# %% [markdown]
# # 5. Cleaning the dataset- Remove the columns having complete NaN value in the entire dataset

# %%
loan.dropna(how="all",axis=1,inplace=True)

# %% [markdown]
# Pandas dropna() method allows the user to analyze and drop Rows/Columns with Null values in different ways.
# yntax DataFrameName.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
#  axis: axis takes int or string value for rows/columns. Input can be 0 or 1 for Integer and ‘index’ or ‘columns’ for String.
# how: how takes string value of two kinds only (‘any’ or ‘all’). ‘any’ drops the row/column if ANY value is Null and ‘all’ drops only if ALL values are null.
#  thresh: thresh takes integer value which tells minimum amount of na values to drop.
#  subset: It’s an array which limits the dropping process to passed rows/columns through list.
#  inplace: It is a boolean which makes the changes in data frame itself if True.

# %% [markdown]
# 21  Unnamed: 21          0 non-null      float64
#  22  Unnamed: 22          0 non-null      float64
#  according to this we have two columns and have all the null values in both the fields

# %%
loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   39717 non-null  int64
#  1   member_id            39717 non-null  int64
#  2   loan_amnt            39717 non-null  int64
#  3   funded_amnt          39717 non-null  int64
#  4   funded_amnt_inv      39717 non-null  float64
#  5   term                 39717 non-null  object
#  6   int_rate             39717 non-null  float64
#  7   installment          39717 non-null  float64
#  8   grade                39717 non-null  object
#  9   emp_length           38642 non-null  object
#  10  annual_inc           39717 non-null  float64
#  11  verification_status  39717 non-null  object
#  12  loan_status          39717 non-null  object
#  13  purpose              39717 non-null  object
#  14  dti                  39717 non-null  float64
# ...

# %%
loan.shape
# Out:
# (39717, 21)

# %% [markdown]
# # 6. Write the code to find the value counts of the ‘loan_status’ category column and filter only the ‘fully paid’ and ‘charged off’ categories.

# %%
loan['loan_status'].value_counts()
# Out:
# Fully Paid     32950
# Charged Off     5627
# Current         1140
# Name: loan_status, dtype: int64

# %%
loan[loan["loan_status"]!="Current"]
# Out:
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0      1077501    1296599       5000         5000           4975.0
# 1      1077430    1314167       2500         2500           2500.0
# 2      1077175    1313524       2400         2400           2400.0
# 3      1076863    1277178      10000        10000          10000.0
# 5      1075269    1311441       5000         5000           5000.0
# ...        ...        ...        ...          ...              ...
# 39712    92187      92174       2500         2500           1075.0
# 39713    90665      90607       8500         8500            875.0
# 39714    90395      90390       5000         5000           1325.0
# 39715    90376      89243       5000         5000            650.0
# 39716    87023      86999       7500         7500            800.0
#
#              term  int_rate  installment grade emp_length  ...  \
# 0       36 months     10.65       162.87     B  10+ years  ...
# ...

# %% [markdown]
# By using the value_counts() method we got three categories in loan_status column fully paid, charged off and current and filter out only two categories fully paid, charged off so it will return 38577 rows × 57 columns matched with these categories

# %% [markdown]
# # 7. Filter the ‘Emp_Len’ column to extract the numerical value from the string

# %%
loan["emp_length"]=loan["emp_length"].str.replace("<","",regex=True).str.replace("years","",regex=True).str.replace("year","",regex=True).str.replace("+","",regex=True)

# %%
loan.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#    int_rate  installment grade emp_length  ...  verification_status  \
# 0     10.65       162.87     B        10   ...             Verified
# 1     15.27        59.83     C         1   ...      Source Verified
# 2     15.96        84.33     C        10   ...         Not Verified
# 3     13.49       339.31     C        10   ...      Source Verified
# 4     12.69        67.79     B         1   ...      Source Verified
#
#    loan_status         purpose    dti   total_pymnt  total_pymnt_inv  \
# ...

# %%
loan["emp_length"]=loan["emp_length"].astype(float)

# %% [markdown]
# his code snippet performs string manipulation on the "emp_length" column of the "loan" dataframe. Specifically, it uses the pandas "str.replace()" method to replace certain substrings within the strings in the "emp_length" column.
#
# The first "str.replace()" call replaces any occurrence of the "<" character with an empty string. This is likely because "<" is used to represent "less than" in the original data, and the code is removing that symbol to obtain a clean integer value.
#
# The second and third "str.replace()" calls remove the substrings "years" and "year" respectively from each string in the column. This is likely because the values in the original "emp_length" column were expressed in terms of years, and the code is removing that string to obtain a clean integer value.
#
# Finally, the fourth "str.replace()" call removes any occurrence of the "+" character from each string. This is likely because some values in the original data were expressed with a "+" symbol to indicate "plus" or "more than", and the code is removing that symbol to obtain a clean integer value.
# Overall, the purpose of this code is to clean and standardize the "emp_length" column of the "loan" dataframe so that it contains only integer values representing the length of employment for each borrower.

# %% [markdown]
# by using this we get only integer value and all <, year, years, + remove from the string of each record

# %%
loan["emp_length"]
# Out:
# 0        10.0
# 1         1.0
# 2        10.0
# 3        10.0
# 4         1.0
#          ...
# 39712     4.0
# 39713     3.0
# 39714     1.0
# 39715     1.0
# 39716     1.0
# Name: emp_length, Length: 39717, dtype: float64

# %%
loan.describe()
# Out:
#                  id     member_id     loan_amnt   funded_amnt  \
# count  3.971700e+04  3.971700e+04  39717.000000  39717.000000
# mean   6.831319e+05  8.504636e+05  11219.443815  10947.713196
# std    2.106941e+05  2.656783e+05   7456.670694   7187.238670
# min    5.473400e+04  7.069900e+04    500.000000    500.000000
# 25%    5.162210e+05  6.667800e+05   5500.000000   5400.000000
# 50%    6.656650e+05  8.508120e+05  10000.000000   9600.000000
# 75%    8.377550e+05  1.047339e+06  15000.000000  15000.000000
# max    1.077501e+06  1.314167e+06  35000.000000  35000.000000
#
#        funded_amnt_inv      int_rate   installment    emp_length  \
# count     39717.000000  39717.000000  39717.000000  38642.000000
# mean      10397.448868     12.021177    324.561922      5.092050
# std        7128.450439      3.724825    208.874874      3.408338
# min           0.000000      5.420000     15.690000      1.000000
# 25%        5000.000000      9.250000    167.020000      2.000000
# ...

# %% [markdown]
# five number summary of the data

# %%
loan["emp_length"]=loan["emp_length"].fillna(loan.emp_length.median())

# %% [markdown]
# median imputation

# %%
loan["emp_length"]=loan["emp_length"].astype(int)

# %% [markdown]
# # 8. Using the Lambda function, remove the month from the ‘term’ column such that ‘36 months’, ‘60 months’ appear as 36 and 60 respectively.

# %%
loan.term=loan["term"].apply(lambda x : x.replace(" months","")).astype(int)

# %%
loan.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  term  \
# 0  1077501    1296599       5000         5000           4975.0    36
# 1  1077430    1314167       2500         2500           2500.0    60
# 2  1077175    1313524       2400         2400           2400.0    36
# 3  1076863    1277178      10000        10000          10000.0    36
# 4  1075358    1311748       3000         3000           3000.0    60
#
#    int_rate  installment grade  emp_length  ...  verification_status  \
# 0     10.65       162.87     B          10  ...             Verified
# 1     15.27        59.83     C           1  ...      Source Verified
# 2     15.96        84.33     C          10  ...         Not Verified
# 3     13.49       339.31     C          10  ...      Source Verified
# 4     12.69        67.79     B           1  ...      Source Verified
#
#    loan_status         purpose    dti   total_pymnt  total_pymnt_inv  \
# ...

# %%
loan.groupby("verification_status").count()
# Out:
#                         id  member_id  loan_amnt  funded_amnt  \
# verification_status
# Not Verified         16921      16921      16921        16921
# Source Verified       9987       9987       9987         9987
# Verified             12809      12809      12809        12809
#
#                      funded_amnt_inv   term  int_rate  installment  grade  \
# verification_status
# Not Verified                   16921  16921     16921        16921  16921
# Source Verified                 9987   9987      9987         9987   9987
# Verified                       12809  12809     12809        12809  12809
#
#                      emp_length  annual_inc  loan_status  purpose    dti  \
# verification_status
# Not Verified              16921       16921        16921    16921  16921
# Source Verified            9987        9987         9987     9987   9987
# Verified                  12809       12809        12809    12809  12809
#
# ...

# %% [markdown]
# loan["term"]: This selects the "term" column from the pandas DataFrame called "loan".
# apply(lambda x : x.replace(" months","")): This applies a lambda function to each value in the "term" column, which replaces the string " months" with an empty string.
# astype(int): This converts the resulting values to integers.
# Assuming that the "term" column in the "loan" DataFrame contains values in the format "<number> months" (e.g. "36 months"), this code would remove the " months" string from each value and convert the remaining number to an integer. The resulting column would contain only integer values representing the loan term in months.

# %% [markdown]
# # 9.  Create a new column as risky_loan_applicant by comparing loan_amnt and funded_amnt with the following criteria -If loan_amnt is less than equals to funded_amnt set it as ‘0’ else set it as ‘1’

# %%
loan["risky_loan"]=[1 if i >j else 0 for i,j in zip(loan["loan_amnt"],loan["funded_amnt"])]

# %%
loan[loan.risky_loan>0]
# Out:
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  term  \
# 61     1068934    1277395      17500         8950      8925.000000    60
# 66     1069093    1303740      12500         8925      8925.000000    60
# 70     1069043    1303486      20975        13575     13550.000000    60
# 77     1068416    1302799       7250         7200      7175.000000    60
# 80     1068994    1303432      35000        22075     22050.000000    60
# ...        ...        ...        ...          ...              ...   ...
# 39533   167645     163382      10000         6000       700.000000    36
# 39593   141774     141767      20000         4800      1949.999594    36
# 39600   140036     140027       4000         1000       550.000000    36
# 39601   139980     139977      12000         5000      1399.996684    36
# 39611   137042     136922      25000         5650       725.000000    36
#
#        int_rate  installment grade  emp_length  ...  loan_status  \
# ...

# %%
loan["risky_loan"].value_counts()
# Out:
# 0    37868
# 1     1849
# Name: risky_loan, dtype: int64

# %% [markdown]
# creates a new column "risky_loan" in the "loan" dataframe, which is based on the values in the "loan_amnt" and "funded_amnt" columns. The purpose of this code is to identify loans that are considered "risky" based on the amount borrowed versus the amount actually funded.
#
# The code uses a list comprehension with a ternary operator to assign a value of 1 or 0 to each element in the "risky_loan" column. Specifically, it checks whether the value in the "loan_amnt" column is greater than the value in the "funded_amnt" column for each row of the dataframe. If it is, the "risky_loan" column is assigned a value of 1 (indicating a risky loan), otherwise it is assigned a value of 0 (indicating a non-risky loan).
#
# The zip() function is used to iterate over both the "loan_amnt" and "funded_amnt" columns simultaneously, and the resulting tuples are used as inputs to the ternary operator inside the list comprehension.
#
# Overall, the resulting "risky_loan" column will contain binary values (0 or 1) indicating whether each loan is considered "risky" based on the amount borrowed versus the amount actually funded.

# %% [markdown]
# # 10. Using the bar plot visualize the loan_status column against categorical column grade, term, verification_status . Write the observation from each graph.

# %%
loan.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  term  \
# 0  1077501    1296599       5000         5000           4975.0    36
# 1  1077430    1314167       2500         2500           2500.0    60
# 2  1077175    1313524       2400         2400           2400.0    36
# 3  1076863    1277178      10000        10000          10000.0    36
# 4  1075358    1311748       3000         3000           3000.0    60
#
#    int_rate  installment grade  emp_length  ...  loan_status         purpose  \
# 0     10.65       162.87     B          10  ...   Fully Paid     credit_card
# 1     15.27        59.83     C           1  ...  Charged Off             car
# 2     15.96        84.33     C          10  ...   Fully Paid  small_business
# 3     13.49       339.31     C          10  ...   Fully Paid           other
# 4     12.69        67.79     B           1  ...      Current           other
#
#      dti   total_pymnt  total_pymnt_inv  total_rec_prncp  total_rec_int  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
loan.loan_status.value_counts()
# Out:
# Fully Paid     32950
# Charged Off     5627
# Current         1140
# Name: loan_status, dtype: int64

# %%
loan.loan_status.value_counts().plot(kind="bar",rot=0,color="lightgrey",edgecolor="black")
for i in range(len(loan.loan_status.value_counts())):
    plt.text(i,loan.loan_status.value_counts()[i],loan.loan_status.value_counts()[i],ha="center",va="bottom")
plt.xlabel("Loan Status")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
import pandas as pd
import matplotlib.pyplot as plt



# create subplots for each categorical column
fig, axs = plt.subplots(ncols=3, figsize=(15,15))

# plot loan_status distribution by grade
ax = loan.groupby(['grade', 'loan_status']).size().unstack().plot(kind='bar', ax=axs[0])
ax.set_title('Loan Status Distribution by Grade')
for i in ax.containers:
    ax.bar_label(i, label_type='edge', fontsize=8)

# plot loan_status distribution by term
ax = loan.groupby(['term', 'loan_status']).size().unstack().plot(kind='bar', ax=axs[1])
ax.set_title('Loan Status Distribution by Term')
for i in ax.containers:
    ax.bar_label(i, label_type='edge', fontsize=8)

# plot loan_status distribution by verification_status
ax = loan.groupby(['verification_status', 'loan_status']).size().unstack().plot(kind='bar', ax=axs[2])
ax.set_title('Loan Status Distribution by Verification Status')
for i in ax.containers:
    ax.bar_label(i, label_type='edge', fontsize=8)

# adjust spacing between subplots and show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # 11.Using a user defined function convert the ‘emp_len’ column into categorical column as follows -
# # If emp_len is less than equals to 1 then recode as ‘fresher’.
# # If emp_len is greater than 1 and less than 3 then recode as ‘junior’.
# # If emp_len is greater than 3 and less than 7 then recode as ‘senior’.
# # If emp_len is greater than 7 then recode as ‘expert’.

# %%
def convert(x):
    new_list=[]
    for i in x:
        if i <=1:
            new_list.append("Fresher")
        elif i>1 and i<=3:
            new_list.append("Junior")
        elif i>3 and i<=7:
            new_list.append("Senior")
        else:
            new_list.append("Expert")
    return new_list

# %%
loan["emp_length"]=convert(loan.emp_length)

# %%
loan["emp_length"].value_counts()
# Out:
# Senior     11795
# Expert     11616
# Junior      8483
# Fresher     7823
# Name: emp_length, dtype: int64

# %%
loan["emp_length"].value_counts()
# Out:
# Senior     11795
# Expert     11616
# Junior      8483
# Fresher     7823
# Name: emp_length, dtype: int64

# %%
loan.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  term  \
# 0  1077501    1296599       5000         5000           4975.0    36
# 1  1077430    1314167       2500         2500           2500.0    60
# 2  1077175    1313524       2400         2400           2400.0    36
# 3  1076863    1277178      10000        10000          10000.0    36
# 4  1075358    1311748       3000         3000           3000.0    60
#
#    int_rate  installment grade emp_length  ...  loan_status         purpose  \
# 0     10.65       162.87     B     Expert  ...   Fully Paid     credit_card
# 1     15.27        59.83     C    Fresher  ...  Charged Off             car
# 2     15.96        84.33     C     Expert  ...   Fully Paid  small_business
# 3     13.49       339.31     C     Expert  ...   Fully Paid           other
# 4     12.69        67.79     B    Fresher  ...      Current           other
#
#      dti   total_pymnt  total_pymnt_inv  total_rec_prncp  total_rec_int  \
# ...

# %% [markdown]
# we first load the loan dataset using the read_csv() method of pandas. Then, we create subplots for each categorical column using the subplots() method of matplotlib. We specify the number of columns, ncols=3, and the size of the figure, figsize=(15,5).
#
# Next, we plot the loan_status distribution by each categorical column using the groupby() method of pandas to group the data by each column, and the size() method to count the number of occurrences of each loan status in each group. We use the unstack() method to reshape the data into a pivot table format before plotting.
#
# For the first subplot, we plot the loan_status distribution by grade. We group the data by both "grade" and "loan_status" columns, and use the unstack() method to reshape the data into a pivot table where each grade is a row and each loan status is a column. This allows us to compare the loan status distribution across different grade levels.
# For the second subplot, we plot the loan_status distribution by term. We group the data by both "term" and "loan_status" columns, and use the unstack() method to reshape the data into a pivot table where each term is a row and each loan status is a column. This allows us to compare the loan status distribution across different loan terms.
#
# For the third subplot, we plot the loan_status distribution by verification_status. We group the data by both "verification_status" and "loan_status" columns, and use the unstack() method to reshape the data into a pivot table where each verification status is a row and each loan status is a column. This allows us to compare the loan status distribution across different verification status categories.
#
# The ax.containers attribute is used to access the individual bar containers in the plot. For each container, the bar_label method is called to add a value label to the edge of the bar. The fontsize parameter can be used to adjust the font size of the labels. Note that the ax variable is used to store the subplot axes so that it can be passed to the bar_label method.

# %% [markdown]
# # 12. Find the sum of ‘loan_amnt’ for each grade and display the distribution of ‘loan_amnt’ using a pie plot .

# %%
loan.groupby(by="grade").loan_amnt.count()
# Out:
# grade
# A    10085
# B    12020
# C     8098
# D     5307
# E     2842
# F     1049
# G      316
# Name: loan_amnt, dtype: int64

# %%
loan.groupby(by="grade").loan_amnt.count().plot.pie(subplots=True,figsize=(15,8),autopct='%.2f%%');

# %% [markdown]
# This pie chart shows percentage loan amount of each grade B have highest loan_amount and G have lowest loan_amount
